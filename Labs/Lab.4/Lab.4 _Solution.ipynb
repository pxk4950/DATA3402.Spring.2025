# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class Counter:
    def __init__(self, max_value):
        self.max_value = max_value
        self.value = 0
    
    def increment(self):
        if self.value < self.max_value:
            self.value += 1
            print ("The counter has been incremented to:",self.value)
        else:
            print("Error: Counter has reached its maximum value.")
    
    def reset(self):
        self.value = 0
        print("The counter has been reset.")
        
#Testing the funsions of class: 
counter = Counter(5)
counter.increment()
counter.increment()
counter.increment()
counter.increment()
counter.increment()
counter.increment()
counter.reset()
counter.increment()
# Out:
# The counter has been incremented to: 1
# The counter has been incremented to: 2
# The counter has been incremented to: 3
# The counter has been incremented to: 4
# The counter has been incremented to: 5
# Error: Counter has reached its maximum value.
# The counter has been reset.
# The counter has been incremented to: 1

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class Counter:
    def __init__(self, max_value):
        self.__max_value = max_value
        self.__value = 0
    
    def increment(self):
        if self.__value < self.__max_value:
            self.__value += 1
            print("The counter has been incremented to:", self.__value)
        else:
            print("Error: Counter has reached its maximum value.")
    
    def reset(self):
        self.__value = 0
        print("The counter has been reset.")
    
    def get_value(self):
        return self.__value
    
    def get_max_value(self):
        return self.__max_value
    
    def is_at_max(self):
        return self.__value == self.__max_value

# Testing the functions of the class:
counter = Counter(5)
counter.increment()
counter.increment()
counter.increment()
counter.increment()
counter.increment()
counter.increment()
print("Current value:", counter.get_value())
print("Maximum value:", counter.get_max_value())
print("Is at max:", counter.is_at_max())
counter.reset()
print("Current value:", counter.get_value())
print("Is at max:", counter.is_at_max())
# Out:
# The counter has been incremented to: 1
# The counter has been incremented to: 2
# The counter has been incremented to: 3
# The counter has been incremented to: 4
# The counter has been incremented to: 5
# Error: Counter has reached its maximum value.
# Current value: 5
# Maximum value: 5
# Is at max: True
# The counter has been reset.
# Current value: 0
# Is at max: False

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Rectangle:
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y
    
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y
    
    def area(self):
        return self.__length * self.__width
    
    def perimeter(self):
        return 2 * (self.__length + self.__width)

# Test of funstions and an example usage:
rect = Rectangle(10, 5, 0, 0)
print("Length:", rect.get_length())
print("Width:", rect.get_width())
print("X Coordinate:", rect.get_x())
print("Y Coordinate:", rect.get_y())
print("Area:", rect.area())
print("Perimeter:", rect.perimeter())
# Out:
# Length: 10
# Width: 5
# X Coordinate: 0
# Y Coordinate: 0
# Area: 50
# Perimeter: 30

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
import math

class Circle:
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y
    
    def get_radius(self):
        return self.__radius
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y
    
    def area(self):
        return math.pi * (self.__radius ** 2)
    
    def perimeter(self):
        return 2 * math.pi * self.__radius

# Test of funstions and an example usage:
circle = Circle(7, 0, 0)
print("Radius:", circle.get_radius())
print("X Coordinate:", circle.get_x())
print("Y Coordinate:", circle.get_y())
print("Area:", circle.area())
print("Perimeter:", circle.perimeter())
# Out:
# Radius: 7
# X Coordinate: 0
# Y Coordinate: 0
# Area: 153.93804002589985
# Perimeter: 43.982297150257104

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
class Shape:
    def __init__(self, x, y):
        self._x = x
        self._y = y
    
    def get_x(self):
        return self._x
    
    def get_y(self):
        return self._y
    
    def area(self):
        raise NotImplementedError("Subclasses must implement this method")
    
    def perimeter(self):
        raise NotImplementedError("Subclasses must implement this method")

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self.__length = length
        self.__width = width
    
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def area(self):
        return self.__length * self.__width
    
    def perimeter(self):
        return 2 * (self.__length + self.__width)

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__(x, y)
        self.__radius = radius
    
    def get_radius(self):
        return self.__radius
    
    def area(self):
        return math.pi * (self.__radius ** 2)
    
    def perimeter(self):
        return 2 * math.pi * self.__radius

# Example usage:
rect = Rectangle(10, 5, 0, 0)
print("Length:", rect.get_length())
print("Width:", rect.get_width())
print("X Coordinate:", rect.get_x())
print("Y Coordinate:", rect.get_y())
print("Area:", rect.area())
print("Perimeter:", rect.perimeter())

circle = Circle(7, 0, 0)
print("Radius:", circle.get_radius())
print("X Coordinate:", circle.get_x())
print("Y Coordinate:", circle.get_y())
print("Area:", circle.area())
print("Perimeter:", circle.perimeter())
# Out:
# Length: 10
# Width: 5
# X Coordinate: 0
# Y Coordinate: 0
# Area: 50
# Perimeter: 30
# Radius: 7
# X Coordinate: 0
# Y Coordinate: 0
# Area: 153.93804002589985
# Perimeter: 43.982297150257104

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Triangle(Shape):
    def __init__(self, side1, side2, side3, x, y):
        super().__init__(x, y)
        self.__side1 = side1
        self.__side2 = side2
        self.__side3 = side3
    
    def get_sides(self):
        return self.__side1, self.__side2, self.__side3
    
    def area(self):
        s = (self.__side1 + self.__side2 + self.__side3) / 2
        return math.sqrt(s * (s - self.__side1) * (s - self.__side2) * (s - self.__side3))
    
    def perimeter(self):
        return self.__side1 + self.__side2 + self.__side3

triangle = Triangle(3, 4, 5, 0, 0)
print("Sides:", triangle.get_sides())
print("X Coordinate:", triangle.get_x())
print("Y Coordinate:", triangle.get_y())
print("Area:", triangle.area())
print("Perimeter:", triangle.perimeter())
# Out:
# Sides: (3, 4, 5)
# X Coordinate: 0
# Y Coordinate: 0
# Area: 6.0
# Perimeter: 12

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
class Shape:
    def __init__(self, x, y):
        self._x = x
        self._y = y
    
    def get_x(self):
        return self._x
    
    def get_y(self):
        return self._y
    
    def area(self):
        raise NotImplementedError("Subclasses must implement this method")
    
    def perimeter(self):
        raise NotImplementedError("Subclasses must implement this method")
    
    def get_perimeter_points(self):
        raise NotImplementedError("Subclasses must implement this method")

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self.__length = length
        self.__width = width
    
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def area(self):
        return self.__length * self.__width
    
    def perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_perimeter_points(self):
        points = []
        
        for i in range(4):
            if i == 0:
                for j in range(4):
                    x_point = self._x + (self.__length / 3) * j
                    y_point = self._y
                    points.append((x_point, y_point))
            elif i == 1:
                for j in range(4):
                    x_point = self._x + self.__length
                    y_point = self._y + (self.__width / 3) * j
                    points.append((x_point, y_point))
            elif i == 2:
                for j in range(4):
                    x_point = self._x + (self.__length / 3) * (3 - j)
                    y_point = self._y + self.__width
                    points.append((x_point, y_point))
            elif i == 3:
                for j in range(4):
                    x_point = self._x
                    y_point = self._y + self.__width - (self.__width / 3) * j
                    points.append((x_point, y_point))

        return points

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__(x, y)
        self.__radius = radius
    
    def get_radius(self):
        return self.__radius
    
    def area(self):
        return math.pi * (self.__radius ** 2)
    
    def perimeter(self):
        return 2 * math.pi * self.__radius
    
    def get_perimeter_points(self):
        thetas = [i * math.pi / 8 for i in range(16)]
        points = []
        for theta in thetas:
            x_point = self._x + self.__radius * math.cos(theta)
            y_point = self._y + self.__radius * math.sin(theta)
            points.append((x_point, y_point))
        return points
    
class Triangle(Shape):
    def __init__(self, side1, side2, side3, x, y):
        super().__init__(x, y)
        self.__side1 = side1
        self.__side2 = side2
        self.__side3 = side3
    
    def get_sides(self):
        return self.__side1, self.__side2, self.__side3
    
    def area(self):
        s = (self.__side1 + self.__side2 + self.__side3) / 2
        return math.sqrt(s * (s - self.__side1) * (s - self.__side2) * (s - self.__side3))
    
    def perimeter(self):
        return self.__side1 + self.__side2 + self.__side3
    
    def get_perimeter_points(self):
        points = []
        
        for i in range(5):
            x_point = self._x + (self.__side1 / 4) * i
            y_point = self._y
            points.append((x_point, y_point))
        
        for i in range(5):
            x_point = self._x + (self.__side2 / 4) * i
            y_point = self._y + (self.__side3 / 4) * i
            points.append((x_point, y_point))
        
        for i in range(5):
            x_point = self._x + self.__side2
            y_point = self._y + (self.__side3 / 4) * i
            points.append((x_point, y_point))
        
        return points
    
# Example usage:
print("For Recatangle:")
rect = Rectangle(10, 5, 0, 0)
print("Length:", rect.get_length())
print("Width:", rect.get_width())
print("X Coordinate:", rect.get_x())
print("Y Coordinate:", rect.get_y())
print("Area:", rect.area())
print("Perimeter:", rect.perimeter())
print("Perimeter Points:", rect.get_perimeter_points())
print("\n")

print("For Circle:")
circle = Circle(7, 0, 0)
print("Radius:", circle.get_radius())
print("X Coordinate:", circle.get_x())
print("Y Coordinate:", circle.get_y())
print("Area:", circle.area())
print("Perimeter:", circle.perimeter())
print("Perimeter Points:", circle.get_perimeter_points())
print("\n")

print("For Triangle:")
triangle = Triangle(3, 4, 5, 0, 0)
print("Sides:", triangle.get_sides())
print("X Coordinate:", triangle.get_x())
print("Y Coordinate:", triangle.get_y())
print("Area:", triangle.area())
print("Perimeter:", triangle.perimeter())
print("Perimeter Points:", triangle.get_perimeter_points())
# Out:
# For Recatangle:
# Length: 10
# Width: 5
# X Coordinate: 0
# Y Coordinate: 0
# Area: 50
# Perimeter: 30
# Perimeter Points: [(0.0, 0), (3.3333333333333335, 0), (6.666666666666667, 0), (10.0, 0), (10, 0.0), (10, 1.6666666666666667), (10, 3.3333333333333335), (10, 5.0), (10.0, 5), (6.666666666666667, 5), (3.3333333333333335, 5), (0.0, 5), (0, 5.0), (0, 3.333333333333333), (0, 1.6666666666666665), (0, 0.0)]
#
#
# For Circle:
# Radius: 7
# X Coordinate: 0
# Y Coordinate: 0
# Area: 153.93804002589985
# Perimeter: 43.982297150257104
# ...

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
import math

class Shape:
    def __init__(self, x, y):
        self._x = x
        self._y = y
    
    def get_x(self):
        return self._x
    
    def get_y(self):
        return self._y
    
    def area(self):
        raise NotImplementedError("Subclasses must implement this method")
    
    def perimeter(self):
        raise NotImplementedError("Subclasses must implement this method")
    
    def get_perimeter_points(self):
        raise NotImplementedError("Subclasses must implement this method")

    def is_inside(self, x_point, y_point):
        raise NotImplementedError("Subclasses must implement this method")

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self.__length = length
        self.__width = width
    
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def area(self):
        return self.__length * self.__width
    
    def perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_perimeter_points(self):
        points = []
        
        for i in range(4):
            if i == 0:
                for j in range(4):
                    x_point = self._x + (self.__length / 3) * j
                    y_point = self._y
                    points.append((x_point, y_point))
            elif i == 1:
                for j in range(4):
                    x_point = self._x + self.__length
                    y_point = self._y + (self.__width / 3) * j
                    points.append((x_point, y_point))
            elif i == 2:
                for j in range(4):
                    x_point = self._x + (self.__length / 3) * (3 - j)
                    y_point = self._y + self.__width
                    points.append((x_point, y_point))
            elif i == 3:
                for j in range(4):
                    x_point = self._x
                    y_point = self._y + self.__width - (self.__width / 3) * j
                    points.append((x_point, y_point))
        
        return points
    
    def is_inside(self, x_point, y_point):
        if self._x <= x_point <= self._x + self.__length and self._y <= y_point <= self._y + self.__width:
            return True
        return False

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__(x, y)
        self.__radius = radius
    
    def get_radius(self):
        return self.__radius
    
    def area(self):
        return math.pi * (self.__radius ** 2)
    
    def perimeter(self):
        return 2 * math.pi * self.__radius
    
    def get_perimeter_points(self):
        thetas = [i * math.pi / 8 for i in range(16)]
        points = []
        for theta in thetas:
            x_point = self._x + self.__radius * math.cos(theta)
            y_point = self._y + self.__radius * math.sin(theta)
            points.append((x_point, y_point))
        return points
    
    def is_inside(self, x_point, y_point):
        distance = math.sqrt((x_point - self._x) ** 2 + (y_point - self._y) ** 2)
        if distance <= self.__radius:
            return True
        return False

class Triangle(Shape):
    def __init__(self, side1, side2, side3, x, y):
        super().__init__(x, y)
        self.__side1 = side1
        self.__side2 = side2
        self.__side3 = side3
    
    def get_sides(self):
        return self.__side1, self.__side2, self.__side3
    
    def area(self):
        s = (self.__side1 + self.__side2 + self.__side3) / 2
        return math.sqrt(s * (s - self.__side1) * (s - self.__side2) * (s - self.__side3))
    
    def perimeter(self):
        return self.__side1 + self.__side2 + self.__side3
    
    def get_perimeter_points(self):
        points = []
        
        for i in range(5):
            x_point = self._x + (self.__side1 / 4) * i
            y_point = self._y
            points.append((x_point, y_point))
        
        for i in range(5):
            x_point = self._x + (self.__side2 / 4) * i
            y_point = self._y + (self.__side3 / 4) * i
            points.append((x_point, y_point))
        
        for i in range(5):
            x_point = self._x + self.__side2
            y_point = self._y + (self.__side3 / 4) * i
            points.append((x_point, y_point))
        
        return points
    
    def is_inside(self, x, y):
        def sign(p1, p2, p3):
            return (p1[0] - p3[0]) * (p2[1] - p3[1]) - (p2[0] - p3[0]) * (p1[1] - p3[1])
        
        p1 = (self._x, self._y)
        p2 = (self._x + self.__side1, self._y)
        p3 = (self._x + self.__side2 / 2, self._y + math.sqrt(self.__side3**2 - (self.__side2 / 2)**2))
        
        d1 = sign((x, y), p1, p2)
        d2 = sign((x, y), p2, p3)
        d3 = sign((x, y), p3, p1)
        
        has_neg = (d1 < 0) or (d2 < 0) or (d3 < 0)
        has_pos = (d1 > 0) or (d2 > 0) or (d3 > 0)
        
        return not (has_neg and has_pos)

# Example usage
print("For Rectangle:")
rect = Rectangle(10, 5, 0, 0)
print("Length:", rect.get_length())
print("Width:", rect.get_width())
print("X Coordinate:", rect.get_x())
print("Y Coordinate:", rect.get_y())
print("Area:", rect.area())
print("Perimeter:", rect.perimeter())
print("Perimeter Points:", rect.get_perimeter_points())
print("Point (3, 3) inside Rectangle:", rect.is_inside(3, 3))
print("Point (12, 12) inside Rectangle:", rect.is_inside(12, 12))

print("\nFor Circle:")
circle = Circle(7, 0, 0)
print("Radius:", circle.get_radius())
print("X Coordinate:", circle.get_x())
print("Y Coordinate:", circle.get_y())
print("Area:", circle.area())
print("Perimeter:", circle.perimeter())
print("Perimeter Points:", circle.get_perimeter_points())
print("Point (3, 3) inside Circle:", circle.is_inside(3, 3))
print("Point (8, 8) inside Circle:", circle.is_inside(8, 8))

print("\nFor Triangle:")
triangle = Triangle(3, 4, 5, 0, 0)
print("Sides:", triangle.get_sides())
print("X Coordinate:", triangle.get_x())
print("Y Coordinate:", triangle.get_y())
print("Area:", triangle.area())
print("Perimeter:", triangle.perimeter())
print("Perimeter Points:", triangle.get_perimeter_points())
print("Point (1, 1) inside Triangle:", triangle.is_inside(1, 1))
print("Point (6, 6) inside Triangle:", triangle.is_inside(6, 6))
# Out:
# For Rectangle:
# Length: 10
# Width: 5
# X Coordinate: 0
# Y Coordinate: 0
# Area: 50
# Perimeter: 30
# Perimeter Points: [(0.0, 0), (3.3333333333333335, 0), (6.666666666666667, 0), (10.0, 0), (10, 0.0), (10, 1.6666666666666667), (10, 3.3333333333333335), (10, 5.0), (10.0, 5), (6.666666666666667, 5), (3.3333333333333335, 5), (0.0, 5), (0, 5.0), (0, 3.333333333333333), (0, 1.6666666666666665), (0, 0.0)]
# Point (3, 3) inside Rectangle: True
# Point (12, 12) inside Rectangle: False
#
# For Circle:
# Radius: 7
# X Coordinate: 0
# Y Coordinate: 0
# Area: 153.93804002589985
# Perimeter: 43.982297150257104
# ...

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
import math

class Shape:
    def __init__(self, x, y):
        self._x = x
        self._y = y
    
    def get_x(self):
        return self._x
    
    def get_y(self):
        return self._y
    
    def area(self):
        raise NotImplementedError("Subclasses must implement this method")
    
    def perimeter(self):
        raise NotImplementedError("Subclasses must implement this method")
    
    def get_perimeter_points(self):
        raise NotImplementedError("Subclasses must implement this method")

    def is_inside(self, x_point, y_point):
        raise NotImplementedError("Subclasses must implement this method")
        
    def is_overlap(self, other):
        if isinstance(other, Shape):
            if isinstance(self, Rectangle) and isinstance(other, Rectangle):
                return self._overlap_with_rectangle(other)
            elif isinstance(self, Circle) and isinstance(other, Circle):
                return self._overlap_with_circle(other)
            elif isinstance(self, Triangle) and isinstance(other, Triangle):
                return self._overlap_with_triangle(other)
        return False
    
    def _overlap_with_rectangle(self, other):
        return not (self._x + self.width < other._x or
                    self._x > other._x + other.width or
                    self._y + self.height < other._y or
                    self._y > other._y + other.height)
    
    def _overlap_with_circle(self, other):
        distance = math.sqrt((self._x - other._x) ** 2 + (self._y - other._y) ** 2)
        return distance < (self.radius + other.radius)
    
    def _overlap_with_triangle(self, other):
        return (self.is_inside(other._x, other._y) or
                other.is_inside(self._x, self._y))


# Rectangle Class
class Rectangle(Shape):
    def __init__(self, x, y, width, height):
        super().__init__(x, y)
        self.width = width
        self.height = height
    
    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)

    def get_perimeter_points(self):
        return [(self._x, self._y), (self._x + self.width, self._y),
                (self._x + self.width, self._y + self.height), (self._x, self._y + self.height)]
    
    def is_inside(self, x_point, y_point):
        return self._x <= x_point <= self._x + self.width and self._y <= y_point <= self._y + self.height


# Circle Class
class Circle(Shape):
    def __init__(self, x, y, radius):
        super().__init__(x, y)
        self.radius = radius
    
    def area(self):
        return math.pi * (self.radius ** 2)
    
    def perimeter(self):
        return 2 * math.pi * self.radius

    def get_perimeter_points(self):
        return [(self._x + self.radius, self._y), (self._x - self.radius, self._y),
                (self._x, self._y + self.radius), (self._x, self._y - self.radius)]
    
    def is_inside(self, x_point, y_point):
        distance = math.sqrt((x_point - self._x) ** 2 + (y_point - self._y) ** 2)
        return distance < self.radius


class Triangle(Shape):
    def __init__(self, side1, side2, side3, x, y):
        super().__init__(x, y)
        self.__side1 = side1
        self.__side2 = side2
        self.__side3 = side3
    
    def get_sides(self):
        return self.__side1, self.__side2, self.__side3
    
    def area(self):
        s = (self.__side1 + self.__side2 + self.__side3) / 2
        return math.sqrt(s * (s - self.__side1) * (s - self.__side2) * (s - self.__side3))
    
    def perimeter(self):
        return self.__side1 + self.__side2 + self.__side3
    
    def get_perimeter_points(self):
        points = []
        
        for i in range(5):
            x_point = self._x + (self.__side1 / 4) * i
            y_point = self._y
            points.append((x_point, y_point))
        
        for i in range(5):
            x_point = self._x + (self.__side2 / 4) * i
            y_point = self._y + (self.__side3 / 4) * i
            points.append((x_point, y_point))
        
        for i in range(5):
            x_point = self._x + self.__side2
            y_point = self._y + (self.__side3 / 4) * i
            points.append((x_point, y_point))
        
        return points
    
    def is_inside(self, x, y):
        def sign(p1, p2, p3):
            return (p1[0] - p3[0]) * (p2[1] - p3[1]) - (p2[0] - p3[0]) * (p1[1] - p3[1])
        
        p1 = (self._x, self._y)
        p2 = (self._x + self.__side1, self._y)
        p3 = (self._x + self.__side2 / 2, self._y + math.sqrt(self.__side3**2 - (self.__side2 / 2)**2))
        
        d1 = sign((x, y), p1, p2)
        d2 = sign((x, y), p2, p3)
        d3 = sign((x, y), p3, p1)
        
        has_neg = (d1 < 0) or (d2 < 0) or (d3 < 0)
        has_pos = (d1 > 0) or (d2 > 0) or (d3 > 0)
        
        return not (has_neg and has_pos)


# Example usage:
rectangle1 = Rectangle(0, 0, 5, 5)
rectangle2 = Rectangle(3, 3, 5, 5)
rectangle3 = Rectangle(6, 6, 3, 3)

circle1 = Circle(0, 0, 5)
circle2 = Circle(4, 0, 3)
circle3 = Circle(10, 10, 2)

triangle1 = Triangle(0, 0, 5, 5,5)
triangle2 = Triangle(2, 2, 5, 5,5)
triangle3 = Triangle(10, 10, 5, 10,3)

# Check overlap
print(rectangle1.is_overlap(rectangle2))  # True, rectangles overlap
print(rectangle1.is_overlap(rectangle3))  # False, rectangles don't overlap

print(circle1.is_overlap(circle2))  # True, circles overlap
print(circle1.is_overlap(circle3))  # False, circles don't overlap

print(triangle1.is_overlap(triangle2))  # True, triangles overlap
print(triangle1.is_overlap(triangle3))  # False, triangles don't overlap
# Out:
# True
# False
# True
# False
# True
# False

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
import paint  #module is in same directory as this solution file

class CompoundShape():
    def __init__(self):
        self.shapes=[]

    def add_shape(self, shape):
        self.shapes.append(shape)

    def paint(self, canvas, char='*'):
        for shape in self.shapes:
            shape.paint(canvas, char)

circle = paint.Circle(10, 10, 6)
rectangle = paint.Rectangle(10, 20, 5, 5)
triangle = paint.Triangle(4, 5, 7, 10, 30)

canvas = paint.Canvas(70,30)

comp_shape = CompoundShape()
comp_shape.add_shape(circle)
comp_shape.add_shape(rectangle)
comp_shape.add_shape(triangle)
comp_shape.paint(canvas)
canvas.display()
# Out:
#
#
#
#
#       * ** * *
#      *        *
#     *          *
#
#     *          *
#
#     *           *   ******    *
#     *          *    *    *    **
#                     *    *    *  *
#     *          *    *    *    *    *
#      *        *     *    *    *
#        **  * *      *****     ** * * *
#           *

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
import paint

class RasterDrawing:
    def __init__(self, canvas):
        self.canvas=canvas
        self.shapes=[]

    def add_shape(self, shape):
        self.shapes.append(shape)

    def paint(self):
        #clears the canvas before painting new shapes
        self.canvas.clear_canvas()
        for shape in self.shapes:
            shape.paint(canvas)

    def modify_shape(self, index, new_shape):
        if 0<=index<len(self.shapes):
            self.shapes[index]=new_shape

    def remove_shape(self, index):
        if 0<=index<len(self.shapes):
            del self.shapes[index]

#test
canvas = paint.Canvas(20, 20)
drawing = RasterDrawing(canvas)

#adds shapes to the drawing
rectangle1 = paint.Rectangle(5, 3, 5, 3)
circle1 = paint.Circle(5, 10, 10)

drawing.add_shape(rectangle1)
drawing.add_shape(circle1)

#first drawing
print("First drawing:")
drawing.paint()
canvas.display()

#change the drawing
print("\nChanging the drawing...")

#changing the rectangle to a larger one
new_rectangle = paint.Rectangle(8, 5, 2, 3)
drawing.modify_shape(0, new_rectangle)

#removing the circle
drawing.remove_shape(1)

#painting the new drawing
print("\nSecond drawing:")
drawing.paint()
canvas.display()
# Out:
# First drawing:
#   * *  *
# *         *
#             *
#
#              *
#    ****
#    *  *
#    *  *       *
#       *
#       *
#    ***         *
#
#               *
#
#
#              *
#
#             *
# *         *
#   *    *
#
# Changing the drawing...
#
# Second drawing:
#
#
#
#
#
#
#
#
#      ****
#      *  *
#      ***

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
from paint import Canvas, Shape, Rectangle, Triangle, Circle

class RasterDrawing:
    def __init__(self,shapes=None,shape_names=None):
        self.canvas = Canvas(50,20)
        if shapes is None:
            self.shapes= dict()
        else: 
            self.shapes=shapes
        if shape_names is None:
            self.shape_names=list()
        else:
            self.shape_names=shape_names

    def add_shape(self,shape):
        # check if shape has name
        if not shape.name or shape.name =="":
            shape.name = self.assign_name()
            
        #check if name already exists
        if shape.name not in self.shapes:
            self.shapes[shape.name]=shape
            self.shape_names.append(shape.name)

    def paint(self):
        #clears the canvas before painting new shapes
        self.canvas.clear_canvas()
        
        for shape in self.shapes.values():
            shape.paint(self.canvas)

        self.canvas.display()


    def modify_shape(self, index, new_shape):
        if 0<=index<len(self.shapes):
            self.shapes[index]=new_shape


    def remove_shape(self, index):
        if 0<=index<len(self.shapes):
            del self.shapes[index]

    def assign_name(self):
        name_base="shape"
        name = name_base+"_0"
        i=1
        
        for name in self.shapes:
            name = name_base+"_"+str(i)
            i+=1
        return name

    def __repr__(self):
        return f"RasterDrawing(shapes={self.shapes}, shape_names={self.shape_names})"

    def save(self, filename):
        with open(filename,"w") as f:
            f.write(repr(self))

    @classmethod
    def loader(cls, filename):
        with open(filename, "r") as f:
            data = f.read()  
        return eval(data)

# %%
#test

drawing = RasterDrawing()

rectangle = Rectangle(10, 20, 5, 5)
circle = Circle(10, 10, 6)
triangle = Triangle(4, 5, 7, 10, 30)

drawing.add_shape(rectangle)
drawing.add_shape(circle)
drawing.add_shape(triangle)
print(drawing.shapes)

drawing.paint()
# Out:
# {'shape_0': Rectangle (10,20,5,5) , 'shape_1': Circle (10,10,6) , 'shape_2': Triangle (4,5,7,10,30) }
#
#
#
#
#       * ** * *
#      *        *
#     *          *
#
#     *          *
#
#     *           *   ******    *
#     *          *    *    *    **
#                     *    *    *  *
#     *          *    *    *    *    *
#      *        *     *    *    *
#        **  * *      *****     ** * * *
#           *

# %%
drawing.save("pic.dat")

# !cat pic.dat
# Out:
# RasterDrawing(shapes={'shape_0': Rectangle (10,20,5,5) , 'shape_1': Circle (10,10,6) , 'shape_2': Triangle (4,5,7,10,30) }, shape_names=['shape_0', 'shape_1', 'shape_2'])

# %%
reloaded_drawing = drawing.loader("pic.dat")

reloaded_drawing.paint()
# Out:
#
#
#
#
#       * ** * *
#      *        *
#     *          *
#
#     *          *
#
#     *           *   ******    *
#     *          *    *    *    **
#                     *    *    *  *
#     *          *    *    *    *    *
#      *        *     *    *    *
#        **  * *      *****     ** * * *
#           *

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')
